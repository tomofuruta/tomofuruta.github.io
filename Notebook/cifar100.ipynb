# %% [markdown]
# ## **Cifar 100 Classification**
# This is a an image classification problem solved using a CNN; specifically a Sequential Keras model.

# %%
import keras
from keras.datasets import cifar100
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Step 1
# Read in the dataset as a dataframe, and explore the data. Understanding the shape of our data will be crucial for creating our model architecture.

# %%
(X_train, y_train), (X_test, y_test) = cifar100.load_data("fine")

print("X_train.shape:",X_train.shape)
print("y_train.shape:",y_train.shape)
print("X_test.shape:",X_test.shape)
print("y_test.shape:",y_test.shape)
class_names = ['apple', 'aquarium_fish','baby','bear','beaver',
               'bed','bee','beetle','bicycle','bottle','bowl',
               'boy','bridge','bus','butterfly','camel','can','castle',
               'caterpillar','cattle','chair','chimpanzee','clock','cloud',
               'cockroach','couch','crab','crocodile','cup','dinosaur','dolphin',
               'elephant','flatfish','forest','fox','girl','hamster','house',
               'kangaroo','keyboard','lamp','lawn_mower','leopard','lion',
               'lizard','lobster','man','maple_tree','motorcycle','mountain',
               'mouse','mushrrom','oak_tree','orange','orchid','otter','palm_tree',
               'pear','pickup_truck','pine_tree','plain','plate','poppy','porcupine',
               'possum','rabbit','raccoon','ray','road','rocket','rose','sea',
               'seal','shark','shrew','skunk','skyscraper','snail','snake',
               'spider','squirrel','streetcar','sunflower','sweet_pepper',
               'table','tank','telephone','television','tiger','tractor',
               'train','trout','tulip','turtle','wardrobe','whale','willow_tree',
               'wolf','woman','worm']
# Out:
# X_train.shape: (50000, 32, 32, 3)
# y_train.shape: (50000, 1)
# X_test.shape: (10000, 32, 32, 3)
# y_test.shape: (10000, 1)

# %% [markdown]
# Print out the first 30 images to get an understanding of the images that we are classifying.

# %%
plt.figure(figsize=[10,10])
for i in range(30):
  plt.subplot(5,6,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(X_train[i])
  plt.xlabel(class_names[y_train[i,0]])
plt.show()

# %% [markdown]
# ### Step 2
# Prepare the data.

# %% [markdown]
# First, convert the X data to float for one-hot encoding.

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# %% [markdown]
# Next, scale the data.

# %%
X_train /= 255
X_test /= 255

# %% [markdown]
# Then create dummy variables for the categorical classes using the to_categorical method. This will be required to run the cross-entropy loss function later on.

# %%
n_classes = 100
print('Shape before one-hot encoding: ',y_train.shape)
Y_train = to_categorical(y_train,n_classes)
Y_test = to_categorical(y_test,n_classes)
print('Shape after one-hot encoding: ', Y_train.shape)
# Out:
# Shape before one-hot encoding:  (50000, 1)
# Shape after one-hot encoding:  (50000, 100)

# %% [markdown]
# ### Step 3
# Build a stack of layers with the sequential model.
# The different layers we can utilize are:
# - Conv2D
#  - A filter/kernel "slides" over the 2D data to perform element-wise multiplication.
# - MaxPool2D
#  - Downsamples the input along is spatial dimensions by taking the maximum value over an input window.
# - Dropout
#  - Randomly deactivates some inputs to prevent overfitting
# - Flatten
#  - Reshapes the output into a dimensional vector, and is used to transition from a convolution layer to a fully connected layer.
# - Dense
#  - Performs a linear operation on the layer's input vector (dot product).

# %%
model = Sequential()

model.add(Conv2D(128,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu',
                 input_shape=(32,32,3)))
model.add(Conv2D(256,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Dropout(.25))

model.add(Conv2D(512,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(.25))

model.add(Flatten())

model.add(Dense(512,activation='relu'))
model.add(Dropout(.4))
model.add(Dense(256,activation='relu'))
model.add(Dropout(.3))

#output
model.add(Dense(100,activation='softmax'))

# %% [markdown]
# We can then run a model.summary() to print out information about the layers.

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_17 (Conv2D)          (None, 32, 32, 128)       3584
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 256)       295168
#
#  max_pooling2d_7 (MaxPoolin  (None, 16, 16, 256)       0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 16, 16, 256)       0
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 512)       1180160
#
#  max_pooling2d_8 (MaxPoolin  (None, 8, 8, 512)         0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 8, 8, 512)         0
#
#  flatten_2 (Flatten)         (None, 32768)             0
#
#  dense_5 (Dense)             (None, 512)               16777728
#
#  dropout_7 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 100)               25700
#
# =================================================================
# Total params: 18413668 (70.24 MB)
# Trainable params: 18413668 (70.24 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 4
# Compile and train the model.
#
# For the compiling step, we must choose our loss function. For our case, we will be using a categorical_crossentropy loss function.
#
# For the training step, we must set certain parameters relating to the epoch. An epoch is the training of the neural network with all the training data for one cycle. The batch_size determines the number of samples we use in one epoch, while the epoch parameter sets the number of epochs the model will run.

# %%
#compile
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

#train
history=model.fit(X_train,Y_train,batch_size=64,epochs=50,validation_data=(X_test,Y_test))
# Out:
# Epoch 1/50
# 782/782 [==============================] - 36s 43ms/step - loss: 2.7761 - accuracy: 0.2960 - val_loss: 2.5815 - val_accuracy: 0.3507
# Epoch 2/50
# 782/782 [==============================] - 33s 43ms/step - loss: 2.6413 - accuracy: 0.3218 - val_loss: 2.5161 - val_accuracy: 0.3617
# Epoch 3/50
# 782/782 [==============================] - 34s 44ms/step - loss: 2.5212 - accuracy: 0.3438 - val_loss: 2.4338 - val_accuracy: 0.3876
# Epoch 4/50
# 782/782 [==============================] - 33s 43ms/step - loss: 2.4093 - accuracy: 0.3678 - val_loss: 2.3775 - val_accuracy: 0.3875
# Epoch 5/50
# 782/782 [==============================] - 34s 43ms/step - loss: 2.3147 - accuracy: 0.3874 - val_loss: 2.3505 - val_accuracy: 0.3951
# Epoch 6/50
# 782/782 [==============================] - 34s 44ms/step - loss: 2.2126 - accuracy: 0.4098 - val_loss: 2.3184 - val_accuracy: 0.4090
# Epoch 7/50
# 782/782 [==============================] - 33s 43ms/step - loss: 2.1305 - accuracy: 0.4242 - val_loss: 2.2904 - val_accuracy: 0.4126
# Epoch 8/50
# 782/782 [==============================] - 34s 44ms/step - loss: 2.0516 - accuracy: 0.4398 - val_loss: 2.2805 - val_accuracy: 0.4099
# Epoch 9/50
# 782/782 [==============================] - 33s 43ms/step - loss: 1.9752 - accuracy: 0.4585 - val_loss: 2.2609 - val_accuracy: 0.4176
# Epoch 10/50
# 782/782 [==============================] - 35s 44ms/step - loss: 1.9208 - accuracy: 0.4725 - val_loss: 2.2680 - val_accuracy: 0.4229
# Epoch 11/50
# 782/782 [==============================] - 34s 44ms/step - loss: 1.8557 - accuracy: 0.4864 - val_loss: 2.2577 - val_accuracy: 0.4222
# Epoch 12/50
# 782/782 [==============================] - 34s 44ms/step - loss: 1.7977 - accuracy: 0.4983 - val_loss: 2.2354 - val_accuracy: 0.4241
# Epoch 13/50
# 782/782 [==============================] - 34s 44ms/step - loss: 1.7456 - accuracy: 0.5120 - val_loss: 2.2170 - val_accuracy: 0.4325
# Epoch 14/50
# 782/782 [==============================] - 34s 43ms/step - loss: 1.7010 - accuracy: 0.5232 - val_loss: 2.2191 - val_accuracy: 0.4305
# Epoch 15/50
# 782/782 [==============================] - 33s 43ms/step - loss: 1.6578 - accuracy: 0.5339 - val_loss: 2.2203 - val_accuracy: 0.4331
# Epoch 16/50
# 782/782 [==============================] - 34s 44ms/step - loss: 1.6043 - accuracy: 0.5459 - val_loss: 2.2707 - val_accuracy: 0.4267
# Epoch 17/50
# 782/782 [==============================] - 33s 43ms/step - loss: 1.5617 - accuracy: 0.5570 - val_loss: 2.2361 - val_accuracy: 0.4321
# Epoch 18/50
# 782/782 [==============================] - 34s 44ms/step - loss: 1.5285 - accuracy: 0.5646 - val_loss: 2.2265 - val_accuracy: 0.4362
# Epoch 19/50
# 782/782 [==============================] - 34s 43ms/step - loss: 1.4914 - accuracy: 0.5756 - val_loss: 2.2244 - val_accuracy: 0.4378
# Epoch 20/50
# 782/782 [==============================] - 34s 44ms/step - loss: 1.4522 - accuracy: 0.5857 - val_loss: 2.2777 - val_accuracy: 0.4330
# Epoch 21/50
# 782/782 [==============================] - 35s 44ms/step - loss: 1.4301 - accuracy: 0.5941 - val_loss: 2.2538 - val_accuracy: 0.4357
# Epoch 22/50
# 782/782 [==============================] - 33s 43ms/step - loss: 1.3955 - accuracy: 0.6009 - val_loss: 2.2377 - val_accuracy: 0.4364
# Epoch 23/50
# 782/782 [==============================] - 33s 43ms/step - loss: 1.3566 - accuracy: 0.6105 - val_loss: 2.2288 - val_accuracy: 0.4422
# Epoch 24/50
# 782/782 [==============================] - 34s 44ms/step - loss: 1.3356 - accuracy: 0.6152 - val_loss: 2.2813 - val_accuracy: 0.4363
# Epoch 25/50
# 782/782 [==============================] - 33s 43ms/step - loss: 1.2950 - accuracy: 0.6253 - val_loss: 2.2869 - val_accuracy: 0.4395
# Epoch 26/50
# 782/782 [==============================] - 34s 43ms/step - loss: 1.2828 - accuracy: 0.6315 - val_loss: 2.2823 - val_accuracy: 0.4316
# Epoch 27/50
# 782/782 [==============================] - 35s 44ms/step - loss: 1.2500 - accuracy: 0.6401 - val_loss: 2.2633 - val_accuracy: 0.4419
# Epoch 28/50
# 782/782 [==============================] - 35s 44ms/step - loss: 1.2191 - accuracy: 0.6468 - val_loss: 2.2910 - val_accuracy: 0.4467
# Epoch 29/50
# 782/782 [==============================] - 33s 43ms/step - loss: 1.2062 - accuracy: 0.6519 - val_loss: 2.2883 - val_accuracy: 0.4416
# Epoch 30/50
# 782/782 [==============================] - 34s 43ms/step - loss: 1.1874 - accuracy: 0.6594 - val_loss: 2.2863 - val_accuracy: 0.4459
# Epoch 31/50
# 782/782 [==============================] - 34s 44ms/step - loss: 1.1637 - accuracy: 0.6625 - val_loss: 2.2957 - val_accuracy: 0.4374
# Epoch 32/50
# 782/782 [==============================] - 35s 44ms/step - loss: 1.1465 - accuracy: 0.6676 - val_loss: 2.3131 - val_accuracy: 0.4430
# Epoch 33/50
# 782/782 [==============================] - 34s 43ms/step - loss: 1.1208 - accuracy: 0.6764 - val_loss: 2.3088 - val_accuracy: 0.4340
# Epoch 34/50
# 782/782 [==============================] - 34s 44ms/step - loss: 1.1031 - accuracy: 0.6810 - val_loss: 2.3205 - val_accuracy: 0.4392
# Epoch 35/50
# 782/782 [==============================] - 34s 44ms/step - loss: 1.0740 - accuracy: 0.6894 - val_loss: 2.3307 - val_accuracy: 0.4413
# Epoch 36/50
# 782/782 [==============================] - 34s 44ms/step - loss: 1.0590 - accuracy: 0.6913 - val_loss: 2.3246 - val_accuracy: 0.4416
# Epoch 37/50
# 782/782 [==============================] - 34s 43ms/step - loss: 1.0568 - accuracy: 0.6932 - val_loss: 2.3056 - val_accuracy: 0.4424
# Epoch 38/50
# 782/782 [==============================] - 34s 43ms/step - loss: 1.0355 - accuracy: 0.7004 - val_loss: 2.3248 - val_accuracy: 0.4409
# Epoch 39/50
# 782/782 [==============================] - 33s 43ms/step - loss: 1.0195 - accuracy: 0.7016 - val_loss: 2.3782 - val_accuracy: 0.4387
# Epoch 40/50
# 782/782 [==============================] - 34s 44ms/step - loss: 1.0058 - accuracy: 0.7084 - val_loss: 2.3379 - val_accuracy: 0.4431
# Epoch 41/50
# 782/782 [==============================] - 35s 44ms/step - loss: 0.9940 - accuracy: 0.7127 - val_loss: 2.3988 - val_accuracy: 0.4409
# Epoch 42/50
# 782/782 [==============================] - 35s 44ms/step - loss: 0.9867 - accuracy: 0.7154 - val_loss: 2.3519 - val_accuracy: 0.4347
# Epoch 43/50
# 782/782 [==============================] - 33s 43ms/step - loss: 0.9645 - accuracy: 0.7181 - val_loss: 2.3675 - val_accuracy: 0.4390
# Epoch 44/50
# 782/782 [==============================] - 34s 43ms/step - loss: 0.9516 - accuracy: 0.7227 - val_loss: 2.3997 - val_accuracy: 0.4411
# Epoch 45/50
# 782/782 [==============================] - 33s 43ms/step - loss: 0.9427 - accuracy: 0.7276 - val_loss: 2.3891 - val_accuracy: 0.4436
# Epoch 46/50
# 782/782 [==============================] - 33s 43ms/step - loss: 0.9304 - accuracy: 0.7313 - val_loss: 2.3700 - val_accuracy: 0.4372
# Epoch 47/50
# 782/782 [==============================] - 34s 43ms/step - loss: 0.9203 - accuracy: 0.7332 - val_loss: 2.3889 - val_accuracy: 0.4338
# Epoch 48/50
# 782/782 [==============================] - 35s 44ms/step - loss: 0.9005 - accuracy: 0.7395 - val_loss: 2.3870 - val_accuracy: 0.4379
# Epoch 49/50
# 782/782 [==============================] - 33s 43ms/step - loss: 0.8923 - accuracy: 0.7406 - val_loss: 2.3734 - val_accuracy: 0.4405
# Epoch 50/50
# 782/782 [==============================] - 34s 44ms/step - loss: 0.8851 - accuracy: 0.7448 - val_loss: 2.4149 - val_accuracy: 0.4413

# %% [markdown]
# ### Step 5
#
# Analyze the model by looking at the loss curve and the accuracy curve.

# %%
#loss curve
plt.figure(figsize=(6,4))
plt.plot(history.history['loss'],'black',linewidth=2.0)
plt.plot(history.history['val_loss'],'green',linewidth=2.0)
plt.legend(['Training Loss','Validation Loss'],fontsize=14)
plt.xlabel('Epochs',fontsize=10)
plt.ylabel('Loss',fontsize=10)
plt.title('Loss Curves',fontsize=12)

#accuracy curve
plt.figure(figsize=(6,4))
plt.plot(history.history['accuracy'],'black',linewidth=2.0)
plt.plot(history.history['val_accuracy'],'blue',linewidth=2.0)
plt.legend(['Training Accuracy','Validation Accuracy'],fontsize=14)
plt.xlabel('Epochs',fontsize=10)
plt.ylabel('Accuracy',fontsize=10)
plt.title('Accuracy Curve',fontsize=12)
# Out:
# Text(0.5, 1.0, 'Accuracy Curve')

# %% [markdown]
# ### Step 6
# Making actual predictions
#
# Now that we have a working model, we can make actual predictions. \
# We must note here that when we predict from the model, we must use argmax to convert into a label index, and then input the label index into the class_names list to get the actual categorical label.

# %%
#predictions
pred=model.predict(X_test)
# convert into label index
pred_classes=np.argmax(pred, axis=1)

#plot actual vs predicted for the first 30 labels.
plt.figure(figsize=[15,15])
for i in range (30):
  plt.subplot(5,6,i+1).imshow(X_test[i])
  plt.subplot(5,6,i+1).set_title("True: %s \nPredict: %s" %
                                 (class_names[y_test[i,0]],
                                  class_names[pred_classes[i]]))
  plt.subplot(5,6,i+1).axis('off')

plt.subplots_adjust(hspace=1)
plt.show()
# Out:
# 313/313 [==============================] - 3s 6ms/step

# %% [markdown]
# If we want to look at just the misclassified labels, we can run the following.

# %%
#misclassified results
failed_indices = []
idx =0

for i in y_test:
  if i[0] != pred_classes[idx]:
    failed_indices.append(idx)
  idx=idx+1

plt.figure(figsize=[15,15])

for i in range(30):
  # for first 30 use
  # failed_index = failed_indices[i]
  random_select = np.random.randint(0,len(failed_indices))
  failed_index = failed_indices[random_select]
  plt.subplot(5,6,i+1).imshow(X_test[failed_index])
  plt.subplot(5,6,i+1).set_title("True: %s \nPredict: %s" %
                                 (class_names[y_test[failed_index,0]],
                                  class_names[pred_classes[failed_index]]))
  plt.subplot(5,6,i+1).axis('off')

plt.subplots_adjust(hspace=1)
plt.show()
